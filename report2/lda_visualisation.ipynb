# %% [markdown]
# # LDA Visualisation

# %%
from Assignments.report2.topic_modeling import *

import pandas as pd
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

n_topics = 20
n_docs = 100

# %%
data = pd.read_csv("news_dataset.csv")["content"]
data = data.dropna().values.tolist()

# %%
dictionary, corpus, texts = preprocess_spacy(data, trigram=True)

# %%
model = build_lda_model(corpus, dictionary, n_topics=n_topics, use_multicore=True)
perplexity, coherence = evaluate_lda(model, dictionary, corpus, texts, use_multicore=True)

# %%
print("Coherence score model:", coherence)
# Out:
# Coherence score model: 0.490280190249727

# %%
mallet_model = build_mallet_model(corpus, dictionary, n_topics=n_topics)
perplexity, coherence_mallet = evaluate_lda(mallet_model, dictionary, corpus, texts, use_multicore=True)
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 597
# total tokens: 6983506
# <10> LL/token: -11.71558
# <20> LL/token: -11.0645
# <30> LL/token: -10.31834
# <40> LL/token: -9.99738
#
# 0	2.5	work build project water car time New_York year find human home small create design climate_change Uber area place bring include
# 1	2.5	Trump Clinton Donald_Trump campaign Hillary_Clinton candidate state vote win election support voter party debate Cruz race lead poll point Sanders
# 2	2.5	time work people thing year good start make Twitter world long idea find ad lot big run day news sponsor
# 3	2.5	company business share sell Facebook include report market buy sale accord bank product service firm deal customer employee year investor
# 4	2.5	man police home family officer die death find mother son father shoot leave child arrest girl victim walk house Police
# ...

# %%
print("Coherence score mallet:", coherence_mallet)
# Out:
# Coherence score mallet: 0.5131154325129239

# %%
converted_model = convertldaGenToldaMallet(mallet_model)
perplexity, coherence_converted = evaluate_lda(converted_model, dictionary, corpus, texts, use_multicore=True)
print("Coherence score converted:", coherence_converted)
# Out:
# Coherence score converted: 0.5131154325129239

# %%
df = format_topics_sentences(converted_model, corpus, texts, n_topics=n_topics, n_docs=n_docs)

# %%
df.to_csv("topic_document_rank.csv", index=False)

# %%
print(converted_model.show_topics(20, 5))
# Out:
# [(0, '0.011*"city" + 0.010*"home" + 0.007*"water" + 0.007*"area" + 0.006*"building"'), (1, '0.043*"Trump" + 0.030*"Clinton" + 0.028*"Donald_Trump" + 0.025*"campaign" + 0.019*"Hillary_Clinton"'), (2, '0.038*"people" + 0.024*"thing" + 0.019*"time" + 0.018*"work" + 0.016*"good"'), (3, '0.038*"company" + 0.015*"business" + 0.010*"share" + 0.009*"sell" + 0.007*"buy"'), (4, '0.022*"man" + 0.022*"police" + 0.014*"report" + 0.013*"officer" + 0.011*"arrest"'), (5, '0.011*"film" + 0.010*"year" + 0.009*"play" + 0.008*"star" + 0.007*"movie"'), (6, '0.024*"country" + 0.013*"year" + 0.012*"government" + 0.008*"Europe" + 0.008*"leave"'), (7, '0.022*"family" + 0.020*"child" + 0.019*"life" + 0.012*"live" + 0.009*"friend"'), (8, '0.040*"woman" + 0.018*"people" + 0.018*"student" + 0.016*"group" + 0.015*"school"'), (9, '0.098*"Trump" + 0.036*"president" + 0.027*"White_House" + 0.025*"Obama" + 0.011*"President_Trump"'), (10, '0.019*"plan" + 0.015*"state" + 0.014*"work" + 0.013*"program" + 0.012*"year"'),
# ...

# %%
p = gensimvis.prepare(model, corpus, dictionary)
p
# Out:
# /Users/stan/virtualenvs/ir/lib/python3.9/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /Users/stan/virtualenvs/ir/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/stan/virtualenvs/ir/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/stan/virtualenvs/ir/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# ...
